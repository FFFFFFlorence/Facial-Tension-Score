# %%
from feat.detector import Detectorv1 as Detector

detector = Detector(
    face_model="retinaface",
    landmark_model="mobilefacenet",
    au_model="xgb",
    emotion_model="resmasknet",
)
# Out:
# ---------------------------------------------------------------------
# ImportError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from feat.detector import Detectorv1 as Detector
#       2
#       3 detector = Detector(
#       4     face_model="retinaface",
#
# File C:\Florence's\Work Environtment\Magang - Imigrasi\Facial Scores\Trial_2 - prototype\.venv-feat\Lib\site-packages\feat\__init__.py:11
#       8 __email__ = "jcheong0428@gmail.com, eshin.jolly@gmail.com, luke.j.chang@dartmouth.edu"
#       9 __all__ = ["detector", "data", "utils", "plotting", "transforms", "__version__"]
# ---> 11 from .data import Fex
#      12 from .detector import Detector
#      13 from .version import __version__
#
# File C:\Florence's\Work Environtment\Magang - Imigrasi\Facial Scores\Trial_2 - prototype\.venv-feat\Lib\site-packages\feat\data.py:17
#      15 from copy import deepcopy
#      16 from functools import reduce
# ---> 17 from nltools.data import Adjacency
#      18 from nltools.stats import downsample, upsample, regress
#      19 from nltools.utils import set_decomposition_algorithm
#
# File C:\Florence's\Work Environtment\Magang - Imigrasi\Facial Scores\Trial_2 - prototype\.venv-feat\Lib\site-packages\nltools\__init__.py:16
#       1 __all__ = [
#       2     "data",
#       3     "datasets",
#    (...)     13     "__version__",
#      14 ]
# ---> 16 from .analysis import Roc
#      17 from .cross_validation import set_cv
#      18 from .data import Brain_Data, Adjacency, Groupby, Design_Matrix, Design_Matrix_Series
#
# File C:\Florence's\Work Environtment\Magang - Imigrasi\Facial Scores\Trial_2 - prototype\.venv-feat\Lib\site-packages\nltools\analysis.py:15
#      13 import numpy as np
#      14 from nltools.plotting import roc_plot
# ---> 15 from scipy.stats import norm, binom_test
#      16 from sklearn.metrics import auc
#      17 from copy import deepcopy
#
# ImportError: cannot import name 'binom_test' from 'scipy.stats' (C:\Florence's\Work Environtment\Magang - Imigrasi\Facial Scores\Trial_2 - prototype\.venv-feat\Lib\site-packages\scipy\stats\__init__.py)

# %%
from feat.detector import Detector

detector = Detector(
    face_model="retinaface",
    landmark_model="mobilefacenet",
    au_model="xgb",
    emotion_model="resmasknet",
)
# Out:
# C:\Florence's\Work Environtment\Magang - Imigrasi\Facial Scores\Trial_2 - prototype\.venv-feat\Lib\site-packages\pandas\core\computation\expressions.py:23: UserWarning: Pandas requires version '2.10.2' or newer of 'numexpr' (version '2.8.4' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# ---------------------------------------------------------------------
# RuntimeError                        Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from feat.detector import Detector
#       2
#       3 detector = Detector(
#       4     face_model="retinaface",
#
# File C:\Florence's\Work Environtment\Magang - Imigrasi\Facial Scores\Trial_2 - prototype\.venv-feat\Lib\site-packages\feat\__init__.py:11
#       8 __email__ = "jcheong0428@gmail.com, eshin.jolly@gmail.com, luke.j.chang@dartmouth.edu"
#       9 __all__ = ["detector", "data", "utils", "plotting", "transforms", "__version__"]
# ---> 11 from .data import Fex
#      12 from .detector import Detector
#      13 from .version import __version__
#
# File C:\Florence's\Work Environtment\Magang - Imigrasi\Facial Scores\Trial_2 - prototype\.venv-feat\Lib\site-packages\feat\data.py:31
#      29 from feat.utils.io import read_feat, read_openface
#      30 from feat.utils.stats import wavelet, calc_hist_auc
# ---> 31 from feat.plotting import plot_face, draw_lineface, draw_facepose, load_viz_model
#      32 from feat.pretrained import AU_LANDMARK_MAP
#      33 from nilearn.signal import clean
#
# File C:\Florence's\Work Environtment\Magang - Imigrasi\Facial Scores\Trial_2 - prototype\.venv-feat\Lib\site-packages\feat\plotting.py:13
#      11 from sklearn.preprocessing import PolynomialFeatures, scale
#      12 import matplotlib.pyplot as plt
# ---> 13 from feat.pretrained import AU_LANDMARK_MAP
#      14 from feat.utils.io import get_resource_path
#      15 from math import sin, cos
#
# File C:\Florence's\Work Environtment\Magang - Imigrasi\Facial Scores\Trial_2 - prototype\.venv-feat\Lib\site-packages\feat\pretrained.py:5
#       1 """
#       2 Helper functions specifically for working with included pre-trained models
#       3 """
# ----> 5 from feat.face_detectors.FaceBoxes.FaceBoxes_test import FaceBoxes
#       6 from feat.face_detectors.Retinaface.Retinaface_test import Retinaface
#       7 from feat.face_detectors.MTCNN.MTCNN_test import MTCNN
#
# File C:\Florence's\Work Environtment\Magang - Imigrasi\Facial Scores\Trial_2 - prototype\.venv-feat\Lib\site-packages\feat\face_detectors\FaceBoxes\__init__.py:1
# ----> 1 from .FaceBoxes_test import FaceBoxes
#
# File C:\Florence's\Work Environtment\Magang - Imigrasi\Facial Scores\Trial_2 - prototype\.venv-feat\Lib\site-packages\feat\face_detectors\FaceBoxes\FaceBoxes_test.py:41
#      36 # from feat.face_detectors.FaceBoxes.FaceBoxes_utils import (
#      37 #     load_model,
#      38 #     nms,
#      39 # )
#      40 from feat.utils.io import get_resource_path
# ---> 41 from feat.utils.image_operations import (
#      42     convert_color_vector_to_tensor,
#      43     decode,
#      44     py_cpu_nms,
#      45 )
#      48 class FaceBoxes:
#      49     def __init__(
#      50         self,
#      51         confidence_threshold=0.05,
#    (...)     57         device="auto",
#      58     ):
#
# File C:\Florence's\Work Environtment\Magang - Imigrasi\Facial Scores\Trial_2 - prototype\.venv-feat\Lib\site-packages\feat\utils\image_operations.py:18
#      16 from torchvision.transforms import PILToTensor, Compose
#      17 import PIL
# ---> 18 from kornia.geometry.transform import warp_affine
#      19 from skimage.morphology.convex_hull import grid_points_in_poly
#      20 from feat.transforms import Rescale
#
# File C:\Florence's\Work Environtment\Magang - Imigrasi\Facial Scores\Trial_2 - prototype\.venv-feat\Lib\site-packages\kornia\__init__.py:28
#      24 from typing import Any
#      26 # NOTE: kornia filters and geometry must go first since are the core of the library
#      27 # and by changing the import order you might get into a circular dependencies issue.
# ---> 28 from . import filters
#      29 from . import geometry
#      31 # import the other modules for convenience
#
# File C:\Florence's\Work Environtment\Magang - Imigrasi\Facial Scores\Trial_2 - prototype\.venv-feat\Lib\site-packages\kornia\filters\__init__.py:64
#      40 from .in_range import InRange, in_range
#      41 from .kernels import (
#      42     gaussian,
#      43     get_binary_kernel2d,
#    (...)     62     laplacian_1d,
#      63 )
# ---> 64 from .kernels_geometry import get_motion_kernel2d, get_motion_kernel3d
#      65 from .laplacian import Laplacian, laplacian
#      66 from .median import MedianBlur, median_blur
#
# File C:\Florence's\Work Environtment\Magang - Imigrasi\Facial Scores\Trial_2 - prototype\.venv-feat\Lib\site-packages\kornia\filters\kernels_geometry.py:25
#      23 from kornia.core.check import KORNIA_CHECK, KORNIA_CHECK_SHAPE
#      24 from kornia.core.utils import _extract_device_dtype
# ---> 25 from kornia.geometry.transform import rotate, rotate3d
#      27 from .kernels import _check_kernel_size, _unpack_2d_ks, _unpack_3d_ks
#      30 def get_motion_kernel2d(
#      31     kernel_size: int, angle: torch.Tensor | float, direction: torch.Tensor | float = 0.0, mode: str = "nearest"
#      32 ) -> torch.Tensor:
#
# File C:\Florence's\Work Environtment\Magang - Imigrasi\Facial Scores\Trial_2 - prototype\.venv-feat\Lib\site-packages\kornia\geometry\__init__.py:28
#      26 from .conversions import *
#      27 from .depth import *
# ---> 28 from .epipolar import *
#      29 from .grid import *
#      30 from .homography import *
#
# File C:\Florence's\Work Environtment\Magang - Imigrasi\Facial Scores\Trial_2 - prototype\.venv-feat\Lib\site-packages\kornia\geometry\epipolar\__init__.py:24
#       1 # LICENSE HEADER MANAGED BY add-license-header
#       2 #
#       3 # Copyright 2018 Kornia Team
#    (...)     15 # limitations under the License.
#      16 #
#      18 from ._metrics import (
#      19     left_to_right_epipolar_distance,
#      20     right_to_left_epipolar_distance,
#      21     sampson_epipolar_distance,
#      22     symmetrical_epipolar_distance,
#      23 )
# ---> 24 from .essential import (
#      25     decompose_essential_matrix,
#      26     decompose_essential_matrix_no_svd,
#      27     essential_from_fundamental,
#      28     essential_from_Rt,
#      29     find_essential,
#      30     motion_from_essential,
#      31     motion_from_essential_choose_solution,
#      32     relative_camera_motion,
#      33 )
#      34 from .fundamental import (
#      35     compute_correspond_epilines,
#      36     find_fundamental,
#    (...)     42     normalize_transformation,
#      43 )
#      44 from .numeric import cross_product_matrix
#
# File C:\Florence's\Work Environtment\Magang - Imigrasi\Facial Scores\Trial_2 - prototype\.venv-feat\Lib\site-packages\kornia\geometry\epipolar\essential.py:119
#     115     cs.scatter_add_(1, batch_coefficient_map, signed_products)
#     116     return cs
# --> 119 @torch.jit.script
#     120 def _solve_2x2_tikhonov_safe(A: torch.Tensor, b: torch.Tensor, eps: float = 1e-12) -> Tuple[torch.Tensor, torch.Tensor]:
#     121     r"""Solve (A)x=b for A (...,2,2), b (...,2,1) using Tikhonov regularization.
#     122
#     123     Uses the following methods:
#    (...)    126     Never throws. Returns (x, bad) where bad marks ill-conditioned A.
#     127     """
#     128     a = A[..., 0, 0]
#
# File C:\Florence's\Work Environtment\Magang - Imigrasi\Facial Scores\Trial_2 - prototype\.venv-feat\Lib\site-packages\torch\jit\_script.py:1341, in script(obj, optimize, _frames_up, _rcb, example_inputs)
#    1339 if _rcb is None:
#    1340     _rcb = _jit_internal.createResolutionCallbackFromClosure(obj)
# -> 1341 fn = torch._C._jit_script_compile(
#    1342     qualified_name, ast, _rcb, get_default_args(obj)
#    1343 )
#    1344 # Forward docstrings
#    1345 fn.__doc__ = obj.__doc__
#
# RuntimeError:
# Arguments for call are not valid.
# The following variants are available:
#
#   aten::any(Tensor self) -> Tensor:
#   Keyword argument dim unknown.
#
#   aten::any.dim(Tensor self, int dim, bool keepdim=False) -> Tensor:
#   Expected a value of type 'int' for argument 'dim' but instead found type 'Tuple[int, int]'.
#
#   aten::any.out(Tensor self, int dim, bool keepdim=False, *, Tensor(a!) out) -> Tensor(a!):
#   Expected a value of type 'int' for argument 'dim' but instead found type 'Tuple[int, int]'.
#
#   aten::any.all_out(Tensor self, *, Tensor(a!) out) -> Tensor(a!):
#   Argument out not provided.
#
#   aten::any.dimname(Tensor self, str dim, bool keepdim=False) -> Tensor:
#   Expected a value of type 'str' for argument 'dim' but instead found type 'Tuple[int, int]'.
#
#   aten::any.dimname_out(Tensor self, str dim, bool keepdim=False, *, Tensor(a!) out) -> Tensor(a!):
#   Expected a value of type 'str' for argument 'dim' but instead found type 'Tuple[int, int]'.
#
#   aten::any.str(str[] self) -> bool:
#   Expected a value of type 'List[str]' for argument 'self' but instead found type 'Tensor'.
#
#   aten::any.int(int[] self) -> bool:
#   Expected a value of type 'List[int]' for argument 'self' but instead found type 'Tensor'.
#
#   aten::any.float(float[] self) -> bool:
#   Expected a value of type 'List[float]' for argument 'self' but instead found type 'Tensor'.
#
#   aten::any.bool(bool[] self) -> bool:
#   Expected a value of type 'List[bool]' for argument 'self' but instead found type 'Tensor'.
#
# The original call is:
#   File "C:\Florence's\Work Environtment\Magang - Imigrasi\Facial Scores\Trial_2 - prototype\.venv-feat\Lib\site-packages\kornia\geometry\epipolar\essential.py", line 187
#
#     # if still non-finite, mark bad and zero it
#     nonfinite = torch.isnan(x).any(dim=(-2, -1)) | torch.isinf(x).any(dim=(-2, -1))
#                 ~~~~~~~~~~~~~~~~~ <--- HERE
#     bad = bad | nonfinite
#     x = torch.where(bad.unsqueeze(-1).unsqueeze(-1), torch.zeros_like(x), x)
